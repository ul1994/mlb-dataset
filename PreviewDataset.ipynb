# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from dataset import *
from utils import *
import matplotlib.pyplot as plt

# %%
dset = MLBDataset(bsize=9)
# Out:
# MLB Dataset (Version 1.0)
#  [*] Found captures: 8
#  [*] Contains people: 15

# %%
(images, masks), (points, pairs) = dset[0]

# %%
plt.figure(figsize=(14, 10))
plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB))
plt.imshow(blend(points[0]), alpha=0.75, cmap='gray')
plt.show(); plt.close()

# %%
plt.figure(figsize=(14, 10))
plt.imshow(cv2.cvtColor(images[0], cv2.COLOR_BGR2RGB))
plt.imshow(blend(pairs[0]), alpha=0.75, cmap='gray')
plt.show(); plt.close()

# %%
plt.figure(figsize=(14, 10))
for ii, img in enumerate(images):
    plt.subplot(3, 3, ii+1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.imshow(1-masks[ii, ..., 0], alpha=0.5, vmin=0, vmax=1, cmap='gray')
#     print(np.sum(points[ii, ..., 1]))
#     plt.imshow(points[ii, ..., 0], alpha=0.75)
    plt.imshow(blend(pairs[ii]), alpha=0.5, cmap='gray')
    plt.imshow(blend(points[ii]), alpha=0.5, cmap='gray')
plt.show(); plt.close()
